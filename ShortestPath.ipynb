# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph
G = nx.Graph()
edges = [(1, 2, 1), (1, 3, 3), (2, 3, 1), (2, 4, 6), (3, 4, 2)]
G.add_weighted_edges_from(edges)

# Compute the minimum spanning tree using Kruskal's algorithm
mst = nx.minimum_spanning_tree(G)

# Draw the original graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True,  edge_color='gray', node_size=700)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

# Draw the minimum spanning tree
nx.draw(mst, pos, with_labels=True,  edge_color='red', node_size=700)
mst_labels = nx.get_edge_attributes(mst, 'weight')
nx.draw_networkx_edge_labels(mst, pos, edge_labels=mst_labels)

# Show the plot
plt.title("Minimum Spanning Tree")
plt.show()

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

# Define the weighted adjacency matrix
# Example: A graph with 4 nodes
# 0 indicates no edge, positive values indicate weights
weighted_adjacency_matrix = np.array([[0, 2, 0, 0],
                                       [2, 0, 3, 1],
                                       [0, 3, 0, 4],
                                       [0, 1, 4, 0]])

# Create a weighted graph from the adjacency matrix
G = nx.from_numpy_array(weighted_adjacency_matrix)

# Draw the weighted graph
pos = nx.spring_layout(G)  # positions for all nodes
nx.draw(G, pos, with_labels=True, node_color='lightblue', edge_color='blue', node_size=300)

# Draw edge labels to show weights
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

plt.title("Weighted Graph from Adjacency Matrix")
plt.show()

# %% [markdown]
# This code will create a graph, compute its minimum spanning tree using Kruskal's algorithm, and then visualize both the original graph and the MST. The MST will be highlighted in a different color for clarity.

# %% [markdown]
# # User
# how do I draw G and mst as two separate graphs?

# %% [markdown]
# # Assistant
# To draw the original graph \( G \) and the minimum spanning tree (MST) as two separate graphs, you can create two different plots using `matplotlib`. You can use subplots to display them side by side or create separate figures for each graph.
#
# Here’s how you can do it using subplots:
#
# 1. **Create a Graph**: Use `networkx` to create a graph and add edges with weights.
# 2. **Compute the MST**: Use the `minimum_spanning_tree` function to compute the MST.
# 3. **Draw Both Graphs**: Use `matplotlib` to create subplots for both the original graph and the MST.
#
# Here’s a code example that demonstrates these steps:

# %% [markdown]
# # User
# Solve the minimum weight spanning tree problem using Kruskal's algorithm

# %% [markdown]
# # Assistant
# To solve the minimum weight spanning tree (MST) problem using Kruskal's algorithm, we will need to write code. Kruskal's algorithm works by sorting all the edges in the graph by their weights and then adding edges to the MST, ensuring that no cycles are formed, until we have included enough edges.
#
# Here’s a step-by-step outline of the algorithm:
#
# 1. **Sort all the edges** in the graph in non-decreasing order of their weights.
# 2. **Initialize** a forest (a set of trees), where each vertex is a separate tree.
# 3. **Pick the smallest edge**. Check if it forms a cycle with the spanning tree formed so far. If it doesn’t, include this edge in the MST.
# 4. **Repeat** step 3 until there are \( V-1 \) edges in the MST (where \( V \) is the number of vertices).
#
# Now, let's implement this in Python using the `networkx` library, which provides a convenient way to work with graphs.

# %%
import networkx as nx

def kruskal_mst(graph):
    # Create a minimum spanning tree using Kruskal's algorithm
    mst = nx.minimum_spanning_tree(graph, algorithm='kruskal')
    return mst

# Example usage
# Create a graph
G = nx.Graph()
edges = [(1, 2, 1), (1, 3, 3), (2, 3, 2), (2, 4, 4), (3, 4, 5)]
G.add_weighted_edges_from(edges)

# Get the minimum spanning tree
mst = kruskal_mst(G)
print("Edges in the Minimum Spanning Tree:")
print(mst.edges(data=True))
# Out:
# Edges in the Minimum Spanning Tree:
# [(1, 2, {'weight': 1}), (2, 3, {'weight': 2}), (2, 4, {'weight': 4})]

# %% [markdown]
# bash
# pip install networkx

# %% [markdown]
# In this code:
# - We create a graph and add weighted edges to it.
# - We then call the `kruskal_mst` function to compute the MST using Kruskal's algorithm.
# - Finally, we print the edges of the resulting minimum spanning tree along with their weights.
#
# Make sure to have the `networkx` library installed in your Python environment to run this code. You can install it using pip if you haven't done so:

# %% [markdown]
# bash
# pip install networkx

# %% [markdown]
# # User
# Solve a shortest path problem using Dijskra's algorithm

# %% [markdown]
# # Assistant
# To solve a shortest path problem using Dijkstra's algorithm, we will need to write code. Below is a Python implementation of Dijkstra's algorithm using a priority queue. This implementation assumes that the graph is represented as an adjacency list.
#
# Here's the code:

# %%
import heapq

def dijkstra(graph, start):
    # Initialize distances and priority queue
    distances = {vertex: float('infinity') for vertex in graph}
    distances[start] = 0
    priority_queue = [(0, start)]  # (distance, vertex)

    while priority_queue:
        current_distance, current_vertex = heapq.heappop(priority_queue)

        # Nodes can only be added once to the priority queue
        if current_distance > distances[current_vertex]:
            continue

        for neighbor, weight in graph[current_vertex].items():
            distance = current_distance + weight

            # Only consider this new path if it's better
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                heapq.heappush(priority_queue, (distance, neighbor))

    return distances

# Example usage:
graph = {
    'A': {'B': 1, 'C': 4},
    'B': {'A': 1, 'C': 2, 'D': 5},
    'C': {'A': 4, 'B': 2, 'D': 1},
    'D': {'B': 5, 'C': 1}
}

start_vertex = 'A'
shortest_paths = dijkstra(graph, start_vertex)
print(shortest_paths)

# %% [markdown]
# ### Explanation:
# 1. **Graph Representation**: The graph is represented as a dictionary where each key is a vertex and its value is another dictionary representing its neighbors and the weights of the edges to those neighbors.
# 2. **Initialization**: We initialize the distances to all vertices as infinity, except for the starting vertex, which is set to 0. A priority queue is used to explore the vertex with the smallest distance.
# 3. **Main Loop**: We pop the vertex with the smallest distance from the priority queue, and for each of its neighbors, we calculate the potential new distance. If this new distance is smaller than the previously recorded distance, we update it and push the neighbor onto the priority queue.
# 4. **Result**: The function returns a dictionary of the shortest distances from the start vertex to all other vertices.
#
# You can run this code in a Jupyter Notebook to see the shortest paths from the starting vertex to all other vertices in the graph.
